# %%
import random

# %%
class NakliLLM:
  def __init__(self):
    print('LLM created')
  
  def predict(self , prompt):

    response_list = [
      'delhi is the capital of india',
      'ips is the indian league',
      'ai stands for the artificial intelligence'
    ]

    return { 'response': random.choice(response_list)}

# %%
print({NakliLLM()})
# Out:
# LLM created
# {<__main__.NakliLLM object at 0x000001CA66A473D0>}
